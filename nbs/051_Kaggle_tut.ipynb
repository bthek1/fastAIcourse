# %% [markdown]
# # Kaggle tutorial
#
# > Kagglle tutorial

# %%
#|eval: false
# install fastkaggle if not available
try: import fastkaggle
except ModuleNotFoundError:
    # !pip install -Uq fastkaggle

from fastkaggle import *

# %% [markdown]
# In [Iterate Like a Grandmaster](https://www.kaggle.com/code/jhoward/iterate-like-a-grandmaster) I explained that when working on a Kaggle project:
#
# > ...the focus generally should be two things:
# >
# > 1. Creating an effective validation set
# > 2. Iterating rapidly to find changes which improve results on the validation set.
#
# Here I'm going to go further, showing the process I used to tackle the [Paddy Doctor](https://www.kaggle.com/competitions/paddy-disease-classification) competition, leading to four submissions in a row which all were (at the time of submission) in 1st place, each one more accurate than the last. You might be surprised to discover that the process of doing this was nearly entirely mechanistic and didn't involve any consideration of the actual data or evaluation details at all.
#
# This notebook is the first in a series showing every step of the process. At the end of this notebook we'll have a basic submission; by the end of the series you'll see how I got to the top of the table!:
#
# <img src="https://user-images.githubusercontent.com/346999/174389920-60d67ead-0f36-41d0-9649-e23b08720c8a.png" width="600"/>

# %% [markdown]
# As a special extra, I'm also opening up early a selection of "walkthru" videos that we've been preparing for the new upcoming fast.ai course. Each day I do a walkthru with fast.ai fellows and registered students, and we record those sessions. They'll all be released at the same time as the next course (probably August 2022), but I'm releasing the ones covering this competition right now! Here they are:
#
# - [Walkthru 8](https://www.youtube.com/watch?v=-Scs4gbwWXg)
# - [Walkthru 9](https://www.youtube.com/watch?v=EK5wJRzffas)
# - [Walkthru 10](https://youtu.be/zhBRynq9Yvo)
# - [Walkthru 11](https://youtu.be/j-zMF2VirA8)
# - [Walkthru 12](https://youtu.be/GuCkpjXHdTc)
# - [Walkthru 13](https://youtu.be/INrkhUGCXHg)
#
# When you're done with this notebook, take a look at [part 2 of the series](https://www.kaggle.com/code/jhoward/small-models-road-to-the-top-part-2/).

# %% [markdown]
# ## Getting set up

# %% [markdown]
# First, we'll get the data. I've just created a new library called [fastkaggle](https://fastai.github.io/fastkaggle/) which has a few handy features, including getting the data for a competition correctly regardless of whether we're running on Kaggle or elsewhere. Note you'll need to first accept the competition rules and join the competition, and you'll need your kaggle API key file `kaggle.json` downloaded if you're running this somewhere other than on Kaggle. `setup_comp` is the function we use in `fastkaggle` to grab the data, and install or upgrade our needed python modules when we're running on Kaggle:

# %%
#|eval: false
comp = 'paddy-disease-classification'

path = setup_comp(comp, install='fastai "timm>=0.6.2.dev0"')

# %%
#|eval: false
path
# Out:
# Path('paddy-disease-classification')

# %% [markdown]
# Now we can import the stuff we'll need from fastai, set a seed (for reproducibility -- just for the purposes of making this notebook easier to write; I don't recommend doing that in your own analysis however) and check what's in the data:

# %%
#|eval: false
from fastai.vision.all import *
set_seed(42)

path.ls()
# Out:
# (#5) [Path('paddy-disease-classification/test_images'),Path('paddy-disease-classification/sample_submission.csv'),Path('paddy-disease-classification/train.csv'),Path('paddy-disease-classification/train_images'),Path('paddy-disease-classification/.ipynb_checkpoints')]

# %% [markdown]
# ## Looking at the data

# %% [markdown]
# The images are in `train_images`, so let's grab a list of all of them:

# %%
#|eval: false
trn_path = path/'train_images'
files = get_image_files(trn_path)

# %% [markdown]
# ...and take a look at one:

# %%
#|eval: false
img = PILImage.create(files[0])
print(img.size)
img.to_thumb(128)
# Out:
# (480, 640)
# <PIL.Image.Image image mode=RGB size=96x128>

# %% [markdown]
# Looks like the images might be 480x640 -- let's check all their sizes. This is faster if we do it in parallel, so we'll use fastcore's `parallel` for this:

# %%
#|eval: false
from fastcore.parallel import *

# %%
#|eval: false
def f(o): return PILImage.create(o).size
sizes = parallel(f, files, n_workers=8)
pd.Series(sizes).value_counts()
# Out:
# (480, 640)    10403
# (640, 480)        4
# Name: count, dtype: int64

# %% [markdown]
# They're nearly all the same size, except for a few. Because of those few, however, we'll need to make sure we always resize each image to common dimensions first, otherwise fastai won't be able to create batches. For now, we'll just squish them to 480x480 images, and then once they're in batches we do a random resized crop down to a smaller size, along with the other default fastai augmentations provided by `aug_transforms`. We'll start out with small resized images, since we want to be able to iterate quickly:

# %%
#|eval: false
dls = ImageDataLoaders.from_folder(trn_path, valid_pct=0.2, seed=42,
    item_tfms=Resize((480,360), method='squish'),
    batch_tfms=aug_transforms(size=(128,128), min_scale=0.75))

dls.show_batch(max_n=6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/mambaforge/envs/cfast/lib/python3.11/site-packages/torch/cuda/__init__.py:260, in _lazy_init()
#     259 try:
# --> 260     queued_call()
#     261 except Exception as e:
#
# File ~/mambaforge/envs/cfast/lib/python3.11/site-packages/torch/cuda/__init__.py:142, in _check_capability()
#     136 old_gpu_warn = """
#     137 Found GPU%d %s which is of cuda capability %d.%d.
#     138 PyTorch no longer supports this GPU because it is too old.
#     139 The minimum cuda capability supported by this library is %d.%d.
#     140 """
# --> 142 if torch.version.cuda is not None:  # on ROCm we don't want this check
#     143     CUDA_VERSION = torch._C._cuda_getCompiledVersion()
#
# AttributeError: module 'torch' has no attribute 'version'
#
# The above exception was the direct cause of the following exception:
#
# DeferredCudaCallError                     Traceback (most recent call last)
# Cell In[14], line 2
#       1 #|eval: false
# ----> 2 dls = ImageDataLoaders.from_folder(trn_path, valid_pct=0.2, seed=42,
#       3     item_tfms=Resize((480,360), method='squish'),
#       4     batch_tfms=aug_transforms(size=(128,128), min_scale=0.75))
#       6 dls.show_batch(max_n=6)
#
# File ~/mambaforge/envs/cfast/lib/python3.11/site-packages/fastai/vision/data.py:123, in ImageDataLoaders.from_folder(cls, path, train, valid, valid_pct, seed, vocab, item_tfms, batch_tfms, img_cls, **kwargs)
#     116 get_items = get_image_files if valid_pct else partial(get_image_files, folders=[train, valid])
#     117 dblock = DataBlock(blocks=(ImageBlock(img_cls), CategoryBlock(vocab=vocab)),
#     118                    get_items=get_items,
#     119                    splitter=splitter,
#     120                    get_y=parent_label,
#     121                    item_tfms=item_tfms,
#     122                    batch_tfms=batch_tfms)
# --> 123 return cls.from_dblock(dblock, path, path=path, **kwargs)
#
# File ~/mambaforge/envs/cfast/lib/python3.11/site-packages/fastai/data/core.py:284, in DataLoaders.from_dblock(cls, dblock, source, path, bs, val_bs, shuffle, device, **kwargs)
#     273 @classmethod
#     274 def from_dblock(cls,
#     275     dblock, # `DataBlock` object
#    (...)
#     282     **kwargs
#     283 ):
# --> 284     return dblock.dataloaders(source, path=path, bs=bs, val_bs=val_bs, shuffle=shuffle, device=device, **kwargs)
#
# File ~/mambaforge/envs/cfast/lib/python3.11/site-packages/fastai/data/block.py:157, in DataBlock.dataloaders(self, source, path, verbose, **kwargs)
#     155 dsets = self.datasets(source, verbose=verbose)
#     156 kwargs = {**self.dls_kwargs, **kwargs, 'verbose': verbose}
# --> 157 return dsets.dataloaders(path=path, after_item=self.item_tfms, after_batch=self.batch_tfms, **kwargs)
#
# File ~/mambaforge/envs/cfast/lib/python3.11/site-packages/fastai/data/core.py:329, in FilteredBase.dataloaders(self, bs, shuffle_train, shuffle, val_shuffle, n, path, dl_type, dl_kwargs, device, drop_last, val_bs, **kwargs)
#     327     shuffle=shuffle_train
#     328     warnings.warn('`shuffle_train` is deprecated. Use `shuffle` instead.',DeprecationWarning)
# --> 329 if device is None: device=default_device()
#     330 if dl_kwargs is None: dl_kwargs = [{}] * self.n_subsets
#     331 if dl_type is None: dl_type = self._dl_type
#
# File ~/mambaforge/envs/cfast/lib/python3.11/site-packages/fastai/torch_core.py:272, in default_device(use)
#     270     if torch.cuda.is_available() or _has_mps(): use = True
#     271 if use:
# --> 272     if torch.cuda.is_available(): return torch.device(torch.cuda.current_device())
#     273     if _has_mps(): return torch.device('mps')
#     274 return torch.device('cpu')
#
# File ~/mambaforge/envs/cfast/lib/python3.11/site-packages/torch/cuda/__init__.py:674, in current_device()
#     672 def current_device() -> int:
#     673     r"""Returns the index of a currently selected device."""
# --> 674     _lazy_init()
#     675     return torch._C._cuda_getDevice()
#
# File ~/mambaforge/envs/cfast/lib/python3.11/site-packages/torch/cuda/__init__.py:264, in _lazy_init()
#     261         except Exception as e:
#     262             msg = (f"CUDA call failed lazily at initialization with error: {str(e)}\n\n"
#     263                    f"CUDA call was originally invoked at:\n\n{orig_traceback}")
# --> 264             raise DeferredCudaCallError(msg) from e
#     265 finally:
#     266     delattr(_tls, 'is_initializing')
#
# DeferredCudaCallError: CUDA call failed lazily at initialization with error: module 'torch' has no attribute 'version'
#
# CUDA call was originally invoked at:
#
# ['  File "<frozen runpy>", line 198, in _run_module_as_main\n', '  File "<frozen runpy>", line 88, in _run_code\n', '  File "/home/ben/mambaforge/envs/cfast/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>\n    app.launch_new_instance()\n', '  File "/home/ben/mambaforge/envs/cfast/lib/python3.11/site-packages/traitlets/config/application.py", line 1046, in launch_instance\n    app.start()\n', '  File "/home/ben/mambaforge/envs/cfast/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 736, in start\n    self.io_loop.start()\n', '  File "/home/ben/mambaforge/envs/cfast/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start\n    self.asyncio_loop.run_forever()\n', '  File "/home/ben/mambaforge/envs/cfast/lib/python3.11/asyncio/base_events.py", line 607, in run_forever\n    self._run_once()\n', '  File "/home/ben/mambaforge/envs/cfast/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once\n    handle._run()\n', '  File "/home/ben/mambaforge/envs/cfast/lib/python3.11/asyncio/events.py", line 80, in _run\n    self._context.run(self._callback, *self._args)\n', '  File "/home/ben/mambaforge/envs/cfast/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue\n    await self.process_one()\n', '  File "/home/ben/mambaforge/envs/cfast/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 505, in process_one\n    await dispatch(*args)\n', '  File "/home/ben/mambaforge/envs/cfast/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell\n    await result\n', '  File "/home/ben/mambaforge/envs/cfast/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 740, in execute_request\n    reply_content = await reply_content\n', '  File "/home/ben/mambaforge/envs/cfast/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 422, in do_execute\n    res = shell.run_cell(\n', '  File "/home/ben/mambaforge/envs/cfast/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 546, in run_cell\n    return super().run_cell(*args, **kwargs)\n', '  File "/home/ben/mambaforge/envs/cfast/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3024, in run_cell\n    result = self._run_cell(\n', '  File "/home/ben/mambaforge/envs/cfast/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3079, in _run_cell\n    result = runner(coro)\n', '  File "/home/ben/mambaforge/envs/cfast/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner\n    coro.send(None)\n', '  File "/home/ben/mambaforge/envs/cfast/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3284, in run_cell_async\n    has_raised = await self.run_ast_nodes(code_ast.body, cell_name,\n', '  File "/home/ben/mambaforge/envs/cfast/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3466, in run_ast_nodes\n    if await self.run_code(code, result, async_=asy):\n', '  File "/home/ben/mambaforge/envs/cfast/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)\n', '  File "/tmp/ipykernel_53595/789558445.py", line 2, in <module>\n    from fastai.vision.all import *\n', '  File "<frozen importlib._bootstrap>", line 1176, in _find_and_load\n', '  File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked\n', '  File "<frozen importlib._bootstrap>", line 690, in _load_unlocked\n', '  File "<frozen importlib._bootstrap_external>", line 940, in exec_module\n', '  File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed\n', '  File "/home/ben/mambaforge/envs/cfast/lib/python3.11/site-packages/fastai/vision/all.py", line 1, in <module>\n    from . import models\n', '  File "<frozen importlib._bootstrap>", line 1232, in _handle_fromlist\n', '  File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed\n', '  File "<frozen importlib._bootstrap>", line 1176, in  ...

# %% [markdown]
# ## Our first model

# %% [markdown]
# Let's create a model. To pick an architecture, we should look at the options in [The best vision models for fine-tuning](https://www.kaggle.com/code/jhoward/the-best-vision-models-for-fine-tuning). I like the looks of `resnet26d`, which is the fastest resolution-independent model which gets into the top-15 lists there.

# %%
import timm

# %%
??timm

# %%
timm.list_models('convnext*')

# %%
#|eval: false
learn = vision_learner(dls, 'resnet26d', metrics=error_rate, path='.').to_fp16()

# %% [markdown]
# Let's see what the learning rate finder shows:

# %%
#|eval: false
learn.lr_find(suggest_funcs=(valley, slide))

# %% [markdown]
# `lr_find` generally recommends rather conservative learning rates, to ensure that your model will train successfully. I generally like to push it a bit higher if I can. Let's train a few epochs and see how it looks:

# %%
#|eval: false
learn.fine_tune(5)

# %% [markdown]
# We're now ready to build our first submission. Let's take a look at the sample Kaggle provided to see what it needs to look like:

# %%
arch = 'convnext_small'

# %%
#|eval: false
learn2 = vision_learner(dls, arch, metrics=error_rate, path='.')

# %%
#|eval: false
learn2.fine_tune(3)

# %% [markdown]
# ## Submitting to Kaggle

# %%
#|eval: false
ss = pd.read_csv(path/'sample_submission.csv')
ss

# %% [markdown]
# OK so we need a CSV containing all the test images, in alphabetical order, and the predicted label for each one. We can create the needed test set using fastai like so:

# %%
#|eval: false
tst_files = get_image_files(path/'test_images').sorted()
tst_dl = dls.test_dl(tst_files)

# %% [markdown]
# We can now get the probabilities of each class, and the index of the most likely class, from this test set (the 2nd thing returned by `get_preds` are the targets, which are blank for a test set, so we discard them):

# %%
#|eval: false
probs,_,idxs = learn2.get_preds(dl=tst_dl, with_decoded=True)
idxs

# %% [markdown]
# These need to be mapped to the names of each of these diseases, these names are stored by fastai automatically in the `vocab`:

# %%
#|eval: false
dls.vocab

# %% [markdown]
# We can create an apply this mapping using pandas:

# %%
#|eval: false
mapping = dict(enumerate(dls.vocab))
results = pd.Series(idxs.numpy(), name="idxs").map(mapping)
results

# %% [markdown]
# Kaggle expects the submission as a CSV file, so let's save it, and check the first few lines:

# %%
#|eval: false
ss['label'] = results
ss.to_csv('subm.csv', index=False)
# !head subm.csv

# %% [markdown]
# Let's submit this to kaggle. We can do it from the notebook if we're running on Kaggle, otherwise we can use the API:

# %%
#|eval: false
if not iskaggle:
    from kaggle import api
    api.competition_submit_cli('subm.csv', 'initial rn26d 128px', comp)

# %% [markdown]
# Success! We successfully created a submission.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Our initial submission is not very good (top 80% of teams) but it only took a minute to train. The important thing is that we have a good starting point to iterate from, and we can do rapid iterations. Every step from loading the data to creating the model to submitting to Kaggle is all automated and runs quickly.
#
# Therefore, we can now try lots of things quickly and easily and use those experiments to improve our results. In the next notebook, we'll do exactly that! So if you're ready, take a look at [part 2 of the series](https://www.kaggle.com/code/jhoward/small-models-road-to-the-top-part-2/).
#
# If you found this notebook useful, please remember to click the little up-arrow at the top to upvote it, since I like to know when people have found my work useful, and it helps others find it too. And if you have any questions or comments, please pop them below -- I read every comment I receive!

# %% [markdown]
# ## Addendum

# %% [markdown]
# `fastkaggle` also provides a function that pushes a notebook to Kaggle Notebooks. I wrote this notebook on my own machine, and pushed it to Kaggle from there -- here's the command I used:

# %%
#|eval: false
if not iskaggle:
    push_notebook('Benson Thekkel', 'first-steps-road-to-the-top-part-1',
                  title='First Steps: Road to the Top, Part 1',
                  file='first-steps-road-to-the-top-part-1.ipynb',
                  competition=comp, private=False, gpu=True)
